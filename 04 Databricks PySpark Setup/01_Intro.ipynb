# %%
import pyspark

# %%
df = sqlContext.sql("SELECT * from mytable")

# %%
print(df.show())
# Out:
# +-----+-----+
# | name|sales|
# +-----+-----+
# | John|  100|
# |Cindy|   86|
# | Carl|  230|
# +-----+-----+
#
# None
